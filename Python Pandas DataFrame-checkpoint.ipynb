# %%
#import libreary 
import pandas as pd

# %%
#empty df 
df=pd.Dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 #empty df
# ----> 2 df=pd.Dataframe
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df=pd.Dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.Dataframe
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df=pd.Dataframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.Dataframe()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df=pd.Dataframe()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.Dataframe()
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd

# %%
df=pd.Dataframe()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.Dataframe()
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.info()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'info'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %%
city=["dhaka","sylhet","barisal","new york"]

# %%
df=pd.DataFrame(city)

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(city)
df
# Out:
#           0
# 0     dhaka
# 1    sylhet
# 2   barisal
# 3  new york

# %%
df=pd.DataFrame('city' ,columns=["city of bd"] ,index=["city1,city2,city3,city4"])
df
# Out:
#                         city of bd
# city1,city2,city3,city4       city

# %%
f=pd.DataFrame(city ,columns=["city of bd"] ,index=["city1,city2,city3,city4"])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 f=pd.DataFrame(city ,columns=["city of bd"] ,index=["city1,city2,city3,city4"])
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
# ...

# %%
df=pd.DataFrame('city' ,columns=["city of bd"] ,index=["city1,city2,city3,city4"])
df
# Out:
#                         city of bd
# city1,city2,city3,city4       city

# %%
df=pd.Dataframe(city)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df=pd.Dataframe(city)
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df=pd.DataFrame(city)
df
# Out:
#           0
# 0     dhaka
# 1    sylhet
# 2   barisal
# 3  new york

# %%
df
# Out:
#           0
# 0     dhaka
# 1    sylhet
# 2   barisal
# 3  new york

# %%
df=pd.DataFrame(city,columns="city of bd")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd")
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# ...

# %%
df=pd.DataFrame(city,columns=["city of bd"])
df
# Out:
#   city of bd
# 0      dhaka
# 1     sylhet
# 2    barisal
# 3   new york

# %%
df=pd.DataFrame(city,columns="city of bd",index=["c1,c2,c2,c4"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd",index=["c1,c2,c2,c4"])
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# ...

# %%
df=pd.DataFrame(city,columns="city of bd",index=["c1","c2","c2","c4"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd",index=["c1","c2","c2","c4"])
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
# ...

# %%
df=pd.DataFrame(city,columns="city of bd", index=["c1","c2","c2","c4"])
dfdf=pd.DataFrame(city,columns="city of bd", index=["c1","c2","c2","c4"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd", index=["c1","c2","c2","c4"])
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
# ...

# %%
df=pd.DataFrame(city,columns="city of bd", index=["c1","c2","c2"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd", index=["c1","c2","c2"])
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
# ...

# %%
df=pd.DataFrame(city,columns="city of bd")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df=pd.DataFrame(city,columns="city of bd")
#       2 df
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# ...

# %%
df=pd.DataFrame(city, index=['c1','c2','c3','c4'])
df
# Out:
#            0
# c1     dhaka
# c2    sylhet
# c3   barisal
# c4  new york

# %%
df=pd.DataFrame(city,columns=["city of bd"])
df
# Out:
#   city of bd
# 0      dhaka
# 1     sylhet
# 2    barisal
# 3   new york

# %%
df=pd.DataFrame(city,columns=["city of bdd"] , index=['c1','c2','c3','c4'])
df
# Out:
#    city of bdd
# c1       dhaka
# c2      sylhet
# c3     barisal
# c4    new york

# %%
city2=["rajshahi","khulna","mirpur","subidbazar"]
df2=pd.DataFrame(zip(city,city2), columns = ["marge city"] , index=['c1','c2','c3','c4'])
df2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
# ...

# %%
city2=["rajshahi","khulna","mirpur","subidbazar"]
df2=pd.DataFrame(zip(city,city2), columns = ['city1','city2'] , index=['c1','c2','c3','c4'])
df2
# Out:
#        city1       city2
# c1     dhaka    rajshahi
# c2    sylhet      khulna
# c3   barisal      mirpur
# c4  new york  subidbazar

# %%
df2.shape
# Out:
# (4, 2)

# %%
city3=[["mirpur,kuril"] , ["gulsan","demra"]]

# %%
df3=pd.DataFrame(city3)
df3
# Out:
#               0      1
# 0  mirpur,kuril   None
# 1        gulsan  demra

# %%
dict1 = {
    
     'city': city1,
     'city2' : city2
    
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 dict1 = {
#       2
# ----> 3      'city': city1,
#       4      'city2' : city2
#       5
#       6 }
#
# NameError: name 'city1' is not defined

# %%
dict1 = {
    
     'city': city,
     'city2' : city2
    
}

# %%
dict1
# Out:
# {'city': ['dhaka', 'sylhet', 'barisal', 'new york'],
#  'city2': ['rajshahi', 'khulna', 'mirpur', 'subidbazar']}

# %%
dfd= pd.DataFrame(dict1)
dfd
# Out:
#        city       city2
# 0     dhaka    rajshahi
# 1    sylhet      khulna
# 2   barisal      mirpur
# 3  new york  subidbazar

# %%
dfd.shape
# Out:
# (4, 2)

# %%
df=pd.read_csv('Screen Time Data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df=pd.read_csv('Screen Time Data')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#    city of bdd
# c1       dhaka
# c2      sylhet
# c3     barisal
# c4    new york

# %%
df=pd.read_csv('Screen Time Data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df=pd.read_csv('Screen Time Data')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('Screen Time Data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df=pd.read_csv('Screen Time Data.csv')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('Screen Time Data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df=pd.read_csv('Screen Time Data.csv')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('F:\excel\Screen Time Data.csv')

# %%
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df.head()
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df.values
# Out:
# array([[0, '04/17/19', 'Wednesday', 187, 89, 17, 41, 22, 0, 0, 0, 0],
#        [1, '04/18/19', 'Thursday', 123, 78, 17, 8, 9, 0, 0, 0, 0],
#        [2, '04/19/19', 'Friday', 112, 52, 40, 8, 4, 0, 3, 0, 0],
#        [3, '04/20/19', 'Saturday', 101, 69, 9, 38, 2, 0, 3, 0, 0],
#        [4, '04/21/19', 'Sunday', 56, 35, 2, 43, 3, 0, 1, 1, 0],
#        [5, '04/22/19', 'Monday', 189, 68, 0, 9, 3, 4, 0, 0, 0],
#        [6, '04/23/19', 'Tuesday', 158, 56, 18, 41, 12, 15, 0, 0, 0],
#        [7, '04/24/19', 'Wednesday', 135, 98, 3, 33, 16, 0, 0, 0, 0],
#        [8, '04/25/19', 'Thursday', 52, 25, 7, 3, 16, 0, 0, 0, 0],
#        [9, '04/26/19', 'Friday', 198, 76, 8, 29, 15, 0, 32, 0, 0],
#        [10, '04/27/19', 'Saturday', 116, 75, 10, 20, 5, 0, 0, 0, 0],
#        [11, '04/28/19', 'Sunday', 85, 42, 22, 4, 2, 0, 0, 0, 0],
#        [12, '04/29/19', 'Monday', 109, 46, 8, 13, 9, 15, 1, 0, 1],
#        [13, '04/30/19', 'Tuesday', 79, 40, 2, 9, 12, 0, 0, 0, 1],
# ...

# %%
df.corr()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9956\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           index  Total Screen Time   Social Networking  \
# index                  1.000000           -0.344952          -0.218093
# Total Screen Time     -0.344952            1.000000           0.710864
# Social Networking     -0.218093            0.710864           1.000000
# Reading and Reference -0.360073            0.185685           0.004461
# Other                 -0.537331            0.333433           0.234066
# Productivity           0.012553            0.344195           0.124539
# Health and Fitness    -0.178863            0.201360          -0.092968
# Entertainment         -0.113858            0.343897           0.132916
# ...
